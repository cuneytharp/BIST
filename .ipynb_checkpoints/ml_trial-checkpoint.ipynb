# %%
import pandas as pd
import pandas_ta as ta
from tvDatafeed import TvDatafeed,TvDatafeedLive,Interval

# %%
tv = TvDatafeed()
ind_df = pd.DataFrame()
# Out:
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited

# %%
stock = "XU100"
exchange = "BIST"
data = tv.get_hist(stock,exchange=exchange,interval=Interval.in_30_minute,n_bars=5000)

# %%
high_ = data["high"]
low_ = data["low"]
open_ = data["open"]
close_ = data["close"]
volume_ =data["volume"]

# %%
#ind_df = pd.concat([ind_df,ta.adx(high=high_,low=low_,close=close_,length=14)],axis=1) #ADX 
ind_df = pd.concat([ind_df,pd.DataFrame(ta.atr(high=high_,low=low_,close=close_,length=14))],axis=1) #atr
#ind_df = pd.concat([ind_df,pd.DataFrame(ta.cci(high=high_,low=low_,close=close_))],axis=1) #atr
#ind_df = pd.concat([ind_df,pd.DataFrame(ta.donchian(high=high_,low=low_))],axis=1) #atr
ind_df = pd.concat([ind_df,pd.DataFrame(ta.ema(close=close_,length=5))],axis=1) #atr
ind_df = pd.concat([ind_df,pd.DataFrame(ta.ema(close=close_,length=8))],axis=1) #atr
ind_df = pd.concat([ind_df,pd.DataFrame(ta.ema(close=close_,length=13))],axis=1) #atr
#ind_df = pd.concat([ind_df,pd.DataFrame(ta.hlc3(high=high_,low=low_,close=close_))],axis=1) #atr
ind_df = pd.concat([ind_df,pd.DataFrame(ta.kama(close=close_))],axis=1) #atr
ind_df = pd.concat([ind_df,pd.DataFrame(ta.linreg(close=close_))],axis=1) #atr
ind_df = pd.concat([ind_df,pd.DataFrame(ta.macd(close=close_))],axis=1) #atr
ind_df = pd.concat([ind_df,pd.DataFrame(ta.obv(volume=volume_,close=close_))],axis=1) #atr
#ind_df = pd.concat([ind_df,pd.DataFrame(ta.roc(close=close_))],axis=1) #atr
ind_df = pd.concat([ind_df,pd.DataFrame(ta.rsi(close=close_))],axis=1) #atr
ind_df = pd.concat([ind_df,pd.DataFrame(ta.stoch(high=high_,low=low_,close=close_))],axis=1) #atr
ind_df = pd.concat([ind_df,pd.DataFrame(ta.supertrend(high=high_,low=low_,close=close_))],axis=1) #atr
ind_df = pd.concat([ind_df,pd.DataFrame(ta.t3(close=close_))],axis=1) #atr
ind_df = pd.concat([ind_df,pd.DataFrame(ta.willr(high=high_,low=low_,close=close_))],axis=1) #atr

# %%
# empty_dict = {}
# for col in ind_df.columns:
#     empty_dict.update({col:0})

# %%
# ind_df = pd.concat([pd.DataFrame(empty_dict,index=[0]),ind_df],axis=0)
# ind_df

# %%
data.reset_index(inplace=True)

# %%
ind_df.reset_index(inplace=True)
ind_df.rename(columns={"datetime":"ind_datetime"},inplace=True)

# %%
master_df = pd.concat([data,ind_df],axis=1)

# %%
master_df[:3]
master_df.set_index("datetime",inplace=True)

# %%
import seaborn as sns

# %%
master_df.drop(["SUPERTs_7_3.0","SUPERTl_7_3.0"],axis=1,inplace=True)

# %%
master_df = master_df.dropna()

# %%
#master_df.rename(columns={"index":"realdatetime"},inplace=True)

# %%
master_df.isnull().sum()
# Out:
# symbol           0
# open             0
# high             0
# low              0
# close            0
# volume           0
# ind_datetime     0
# ATRr_14          0
# EMA_5            0
# EMA_8            0
# EMA_13           0
# KAMA_10_2_30     0
# LR_14            0
# MACD_12_26_9     0
# MACDh_12_26_9    0
# MACDs_12_26_9    0
# OBV              0
# RSI_14           0
# STOCHk_14_3_3    0
# STOCHd_14_3_3    0
# SUPERT_7_3.0     0
# SUPERTd_7_3.0    0
# T3_10_0.7        0
# WILLR_14         0
# dtype: int64

# %%
#master_df["realdatetime"]  = pd.to_datetime(master_df["realdatetime"])

# %%
#master_df.set_index("realdatetime",inplace=True)

# %%
X = master_df.iloc[:, 8:]
y = master_df["close"]
X
# Out:
#                            EMA_5        EMA_8       EMA_13  KAMA_10_2_30  \
# datetime
# 2022-12-02 15:00:00  4995.570868  4999.400563  5006.665509   4666.164128
# 2022-12-02 15:30:00  5000.930579  5002.122660  5007.377579   4674.976627
# 2022-12-02 16:00:00  5002.990386  5003.230958  5007.339353   4677.498686
# 2022-12-02 16:30:00  4993.793591  4997.046301  5002.776589   4691.447606
# 2022-12-02 17:00:00  4985.595727  4990.858234  4997.979933   4701.405446
# ...                          ...          ...          ...           ...
# 2024-01-12 16:00:00  7991.800205  7961.830881  7933.622314   7975.912361
# 2024-01-12 16:30:00  8017.746804  7985.788463  7953.053412   8008.107439
# 2024-01-12 17:00:00  8031.304536  8001.928804  7968.105782   8024.704870
# 2024-01-12 17:30:00  8015.706357  7998.057959  7970.449241   8019.629532
# 2024-01-12 18:00:00  8005.960905  7995.482857  7972.737921   8015.909205
#
#                            LR_14  MACD_12_26_9  MACDh_12_26_9  MACDs_12_26_9  \
# datetime
# 2022-12-02 15:00:00  4983.466923    -14.830143      -2.979058     -11.851085
# 2022-12-02 15:30:00  4986.716418    -13.228272      -1.101749     -12.126522
# 2022-12-02 16:00:00  4989.818088    -12.184659      -0.046510     -12.138150
# 2022-12-02 16:30:00  4987.527538    -13.757731      -1.295665     -12.462066
# 2022-12-02 17:00:00  4984.884418    -15.327998      -2.292745     -13.035252
# ...                          ...           ...            ...            ...
# 2024-01-12 16:00:00  7991.170703     35.356967      19.881185      15.475782
# 2024-01-12 16:30:00  8027.489824     43.253409      22.222101      21.031308
# 2024-01-12 17:00:00  8051.339604     48.052121      21.616651      26.435470
# 2024-01-12 17:30:00  8049.591758     45.368239      15.146215      30.222024
# 2024-01-12 18:00:00  8049.074681     42.904818      10.146236      32.758583
#
#                               OBV     RSI_14  STOCHk_14_3_3  STOCHd_14_3_3  \
# datetime
# 2022-12-02 15:00:00 -1.178230e+09  40.734944      40.161677      36.082024
# 2022-12-02 15:30:00 -9.673919e+08  48.708814      43.259291      41.053738
# 2022-12-02 16:00:00 -1.149572e+09  47.283324      44.611367      42.677445
# 2022-12-02 16:30:00 -1.505357e+09  38.752653      39.480930      42.450529
# 2022-12-02 17:00:00 -1.892976e+09  37.334366      29.429048      37.840449
# ...                           ...        ...            ...            ...
# 2024-01-12 16:00:00  6.537436e+10  72.289178      97.628794      97.663678
# 2024-01-12 16:30:00  6.561635e+10  74.044357      96.784761      97.410623
# 2024-01-12 17:00:00  6.540829e+10  71.581081      94.499657      96.304404
# 2024-01-12 17:30:00  6.510838e+10  57.913394      85.467911      92.250776
# 2024-01-12 18:00:00  6.517265e+10  58.141647      74.815973      84.927847
#
#                      SUPERT_7_3.0  SUPERTd_7_3.0    T3_10_0.7   WILLR_14
# datetime
# 2022-12-02 15:00:00   5050.888075             -1  5004.745936 -69.374396
# 2022-12-02 15:30:00   5050.888075             -1  5000.838369 -45.959867
# 2022-12-02 16:00:00   5050.888075             -1  4998.062522 -50.831634
# 2022-12-02 16:30:00   5050.888075             -1  4995.564169 -84.765709
# 2022-12-02 17:00:00   5041.141436             -1  4992.844333 -76.115511
# ...                           ...            ...          ...        ...
# 2024-01-12 16:00:00   7923.204706              1  7887.286562  -4.989018
# 2024-01-12 16:30:00   7945.874748              1  7907.142067  -3.927512
# 2024-01-12 17:00:00   7945.874748              1  7929.041078  -7.584499
# 2024-01-12 17:30:00   7945.874748              1  7949.856552 -32.084255
# 2024-01-12 18:00:00   7945.874748              1  7968.023531 -35.883328
#
# [4967 rows x 16 columns]

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
scaler= StandardScaler()
scaled_x  = scaler.fit_transform(X)

# %%
X.shape
# Out:
# (4967, 16)

# %%
X_train= X[:3000] 
X_test = X[3000:]
y_train= y[:3000]
y_test = y[3000:]

# %%
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
import matplotlib.pyplot as plt

# %%
def model_evaluate(model,X_train,y_train,X_test,y_test):
    model.fit(X_train,y_train)
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)
    print("Model Name:",model)
    print("train: R2score",r2_score(y_train,train_pred)," mse:",mean_squared_error(y_train,train_pred))
    print("test: R2score",r2_score(y_test,test_pred)," mse:",mean_squared_error(y_test,test_pred))
    plt.plot(y_test.index, y_test.values)
    plt.plot(y_test.index, test_pred)
    plt.show()

# %%
rfr= RandomForestRegressor()
ada = AdaBoostRegressor()
lrm = LinearRegression()
gbr = GradientBoostingRegressor()
list_of_models = [rfr,ada,lrm,gbr]

# %%
for model in list_of_models:
    model_evaluate(model,X_train,y_train,X_test,y_test)
# Out:
# Model Name: RandomForestRegressor()
# train: R2score 0.9999345147793687  mse: 32.89139853638578
# test: R2score -0.3672825052211839  mse: 109205.235726294
# Model Name: AdaBoostRegressor()
# train: R2score 0.9958749188452428  mse: 2071.9131270850803
# test: R2score -1.0540121134411309  mse: 164054.52141488186
# Model Name: LinearRegression()
# train: R2score 0.9999408615732667  mse: 29.703581109581624
# test: R2score 0.9995784360813902  mse: 33.67042796911656
# Model Name: GradientBoostingRegressor()
# train: R2score 0.999757707701533  mse: 121.69665879332236
# test: R2score -0.3972241078461227  mse: 111596.67989397209
